# %% [markdown]
# #Los operadores lógicos

# %% [markdown]
# Recordemos los operadores de comparación
#
# ![img1](https://facialix.com/images/cond.png)

# %% [markdown]
# y veamos algunos ejemplos de los operadores logicos en acción
#
# ![img2](https://facialix.com/images/logicos.png)

# %% [markdown]
# **En este ejercicio debes mostrar el valor que se obtiene de las sentencias al ejecutarlas en codigo y explicarlas:**

# %% [markdown]
# 1) **not true**

# %%
#Escribe el codigo aquí
not True
# Out:
# False

# %% [markdown]
# En este caso 'not True' es sinónimo de 'Falso'
#
# 🖍 ...

# %% [markdown]
# 2) **not (1+2 != 3)**

# %%
#Escribe el codigo aquí
not (1+2 != 3)
# Out:
# True

# %% [markdown]
# En la expresión 1+2 no es distinto que 3, entonces es verdadero
# 🖍 ...

# %% [markdown]
# 3) **x = (len("jugar") > 5) and (len("jugar") < 10)**

# %%
#Escribe el codigo aquí
x = (len("jugar") > 5) and (len("jugar") < 10)

# %% [markdown]
# la primera expresión es falsa, y la seguda verdadera, por lo que x sería Falsa
#
# 🖍 ...

# %% [markdown]
# 4) **"alto"[2] == "t" and x**

# %%
#Escribe el codigo aquí
"alto"[2] == "t" and x
# Out:
# False

# %% [markdown]
# La primera condición si se cumple, siendo verdadera, sin embargo, la segunda ya no, por lo consecuente, genera un false.
#
# 🖍 ...

# %% [markdown]
# 5) **842913%10 != 3 and len("café") == 3**

# %%
#Escribe el codigo aquí
842913%10 != 3 and len("café") == 3
# Out:
# False

# %% [markdown]
# Ambas expresioes son falsas, por lo consecuente, es falsa.
#
# 🖍 ...

# %% [markdown]
# 6) **0!=0 or "a" < "y"**

# %%
#Escribe el codigo aquí
0!=0 or "a" < "y"
# Out:
# True

# %% [markdown]
# Con que se cumpla una expresión es verdadero, siendo la segunda expresión verdadera.
#
# 🖍 ...

# %% [markdown]
# 7) **True or int("50") >= 50**

# %%
#Escribe el codigo aquí
True or int("50") >= 50
# Out:
# True

# %% [markdown]
# Hay un True en una de las expresiones, por lo que es verdadera.
#
# 🖍 ...

# %% [markdown]
# 8) **edad = 20**
#
# **not(x) or edad%2==0**

# %%
#Escribe el codigo aquí

edad = 20

not(x) or edad%2==0
# Out:
# True

# %% [markdown]
# La seguda expresión es verdadera, convirtiendo en verdadero toda la oración
#
# 🖍 ...

# %% [markdown]
# 9) **es_cliente = False**
#
# **not (es_cliente and not(edad < 18))**

# %%
#Escribe el codigo aquí
es_cliente = False

not (es_cliente and not(edad < 18))
# Out:
# True

# %% [markdown]
# Al haber una doble negación, se hace verdadero
#
# 🖍 ...

# %% [markdown]
# ###Recursos extra para estudiar y ejercios

# %% [markdown]
# - Video corto de Coursera: [Tablas de verdad y álgebra booleana](https://www.coursera.org/lecture/programacion-python/tablas-de-verdad-y-algebra-booleana-JJs0E)
# - Articulo corto de [Tablas de la verdad](https://www.ecured.cu/Tablas_de_la_verdad)
# - Ejercicios practicos en portal de [Tablas de Verdad](https://www.edu.xunta.gal/espazoAbalar/sites/espazoAbalar/files/datos/1493724904/contido/tablas_de_verdad.html)
# - Guía de [Ejercicios de Lógica](https://www.fing.edu.uy/tecnoinf/mvd/cursos/mdl1/material/pra/buceo_noct/mdl1-pr-logica.pdf)
